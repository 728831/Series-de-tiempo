# %%
import pandas as pd
from matplotlib import pyplot as plt
import yfinance as yf
# %matplotlib inline

# %%
btc = pd.read_csv('BTC-USD.csv')['Adj Close']
btc = pd.DataFrame(btc)

# %%
kw = pd.read_csv('KW-USD.csv')['Value']
kw = pd.DataFrame(kw)

# %%
plt.figure(figsize=(6,4));
plt.plot(kw)
plt.plot(btc)

# %%
stocks = ['NEE', 'AU']
data = yf.download(stocks, start='2015-01-01')['Adj Close']
print(data.head())
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Ticker            AU        NEE
# Date
# 2015-01-02  7.970395  20.930887
# 2015-01-05  8.324433  20.709196
# 2015-01-06  8.841873  20.789635
# 2015-01-07  8.678471  20.979931
# 2015-01-08  8.687549  21.107450

# %%
data.plot(figsize=(8, 6),
            grid=True)
# Out:
# <Axes: xlabel='Date'>
